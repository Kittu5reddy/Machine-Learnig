# %%
#importing
#loading files file -> df and df -> files
#looksups(head,tail,accessing columns,loc,iloc,info)
#adding(columns,rows)
#droping rows , columns , setting index 
#staticial values(summary)
#cleaning(isnull,notnull,dropna,fillna())
#replace
#joins
#groupby
#dublicates duplicated()  drop_duplicates()

# %%
import pandas as pd

# %%
df=pd.read_csv("Data.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.sepal_length
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
df['sepal_length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
df
# Out:
#      Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# 0             0           5.1          3.5           1.4          0.2
# 1             1           4.9          3.0           1.4          0.2
# 2             2           4.7          3.2           1.3          0.2
# 3             3           4.6          3.1           1.5          0.2
# 4             4           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         145           6.7          3.0           5.2          2.3
# 146         146           6.3          2.5           5.0          1.9
# 147         147           6.5          3.0           5.2          2.0
# 148         148           6.2          3.4           5.4          2.3
# 149         149           5.9          3.0           5.1          1.8
#
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width species
# 0           0           5.1          3.5           1.4          0.2  setosa
# 1           1           4.9          3.0           1.4          0.2  setosa
# 2           2           4.7          3.2           1.3          0.2  setosa
# 3           3           4.6          3.1           1.5          0.2  setosa
# 4           4           5.0          3.6           1.4          0.2  setosa

# %%
df.head(10)
# Out:
#    Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width species
# 0           0           5.1          3.5           1.4          0.2  setosa
# 1           1           4.9          3.0           1.4          0.2  setosa
# 2           2           4.7          3.2           1.3          0.2  setosa
# 3           3           4.6          3.1           1.5          0.2  setosa
# 4           4           5.0          3.6           1.4          0.2  setosa
# 5           5           5.4          3.9           1.7          0.4  setosa
# 6           6           4.6          3.4           1.4          0.3  setosa
# 7           7           5.0          3.4           1.5          0.2  setosa
# 8           8           4.4          2.9           1.4          0.2  setosa
# 9           9           4.9          3.1           1.5          0.1  setosa

# %%
df.head(50)
# Out:
#     Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width species
# 0            0           5.1          3.5           1.4          0.2  setosa
# 1            1           4.9          3.0           1.4          0.2  setosa
# 2            2           4.7          3.2           1.3          0.2  setosa
# 3            3           4.6          3.1           1.5          0.2  setosa
# 4            4           5.0          3.6           1.4          0.2  setosa
# 5            5           5.4          3.9           1.7          0.4  setosa
# 6            6           4.6          3.4           1.4          0.3  setosa
# 7            7           5.0          3.4           1.5          0.2  setosa
# 8            8           4.4          2.9           1.4          0.2  setosa
# 9            9           4.9          3.1           1.5          0.1  setosa
# 10          10           5.4          3.7           1.5          0.2  setosa
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# 145         145           6.7          3.0           5.2          2.3
# 146         146           6.3          2.5           5.0          1.9
# 147         147           6.5          3.0           5.2          2.0
# 148         148           6.2          3.4           5.4          2.3
# 149         149           5.9          3.0           5.1          1.8
#
#        species
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica

# %%
df.tail(20)
# Out:
#      Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# 130         130           7.4          2.8           6.1          1.9
# 131         131           7.9          3.8           6.4          2.0
# 132         132           6.4          2.8           5.6          2.2
# 133         133           6.3          2.8           5.1          1.5
# 134         134           6.1          2.6           5.6          1.4
# 135         135           7.7          3.0           6.1          2.3
# 136         136           6.3          3.4           5.6          2.4
# 137         137           6.4          3.1           5.5          1.8
# 138         138           6.0          3.0           4.8          1.8
# 139         139           6.9          3.1           5.4          2.1
# 140         140           6.7          3.1           5.6          2.4
# 141         141           6.9          3.1           5.1          2.3
# ...

# %%
df
# Out:
#      Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# 0             0           5.1          3.5           1.4          0.2
# 1             1           4.9          3.0           1.4          0.2
# 2             2           4.7          3.2           1.3          0.2
# 3             3           4.6          3.1           1.5          0.2
# 4             4           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         145           6.7          3.0           5.2          2.3
# 146         146           6.3          2.5           5.0          1.9
# 147         147           6.5          3.0           5.2          2.0
# 148         148           6.2          3.4           5.4          2.3
# 149         149           5.9          3.0           5.1          1.8
#
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
df=df[["sepal_length","sepal_width","petal_width","petal_length","species"]]

# %%
df
# Out:
#      sepal_length  sepal_width  petal_width  petal_length    species
# 0             5.1          3.5          0.2           1.4     setosa
# 1             4.9          3.0          0.2           1.4     setosa
# 2             4.7          3.2          0.2           1.3     setosa
# 3             4.6          3.1          0.2           1.5     setosa
# 4             5.0          3.6          0.2           1.4     setosa
# ..            ...          ...          ...           ...        ...
# 145           6.7          3.0          2.3           5.2  virginica
# 146           6.3          2.5          1.9           5.0  virginica
# 147           6.5          3.0          2.0           5.2  virginica
# 148           6.2          3.4          2.3           5.4  virginica
# 149           5.9          3.0          1.8           5.1  virginica
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_width   150 non-null    float64
#  3   petal_length  150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_width  petal_length
# count    150.000000   150.000000   150.000000    150.000000
# mean       5.843333     3.057333     1.199333      3.758000
# std        0.828066     0.435866     0.762238      1.765298
# min        4.300000     2.000000     0.100000      1.000000
# 25%        5.100000     2.800000     0.300000      1.600000
# 50%        5.800000     3.000000     1.300000      4.350000
# 75%        6.400000     3.300000     1.800000      5.100000
# max        7.900000     4.400000     2.500000      6.900000

# %%
df
# Out:
#      sepal_length  sepal_width  petal_width  petal_length    species
# 0             5.1          3.5          0.2           1.4     setosa
# 1             4.9          3.0          0.2           1.4     setosa
# 2             4.7          3.2          0.2           1.3     setosa
# 3             4.6          3.1          0.2           1.5     setosa
# 4             5.0          3.6          0.2           1.4     setosa
# ..            ...          ...          ...           ...        ...
# 145           6.7          3.0          2.3           5.2  virginica
# 146           6.3          2.5          1.9           5.0  virginica
# 147           6.5          3.0          2.0           5.2  virginica
# 148           6.2          3.4          2.3           5.4  virginica
# 149           5.9          3.0          1.8           5.1  virginica
#
# [150 rows x 5 columns]

# %%
df=df.set_index("sepal_length")#->new dataframe with sepeal_length index

# %%
df=df.reset_index()

# %%
df
# Out:
#      sepal_length  sepal_width  petal_width  petal_length    species
# 0             5.1          3.5          0.2           1.4     setosa
# 1             4.9          3.0          0.2           1.4     setosa
# 2             4.7          3.2          0.2           1.3     setosa
# 3             4.6          3.1          0.2           1.5     setosa
# 4             5.0          3.6          0.2           1.4     setosa
# ..            ...          ...          ...           ...        ...
# 145           6.7          3.0          2.3           5.2  virginica
# 146           6.3          2.5          1.9           5.0  virginica
# 147           6.5          3.0          2.0           5.2  virginica
# 148           6.2          3.4          2.3           5.4  virginica
# 149           5.9          3.0          1.8           5.1  virginica
#
# [150 rows x 5 columns]

# %%
pd.read_json("Data.json")
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
df.tail(10)
# Out:
#      sepal_length  sepal_width  petal_width  petal_length    species
# 140           6.7          3.1          2.4           5.6  virginica
# 141           6.9          3.1          2.3           5.1  virginica
# 142           5.8          2.7          1.9           5.1  virginica
# 143           6.8          3.2          2.3           5.9  virginica
# 144           6.7          3.3          2.5           5.7  virginica
# 145           6.7          3.0          2.3           5.2  virginica
# 146           6.3          2.5          1.9           5.0  virginica
# 147           6.5          3.0          2.0           5.2  virginica
# 148           6.2          3.4          2.3           5.4  virginica
# 149           5.9          3.0          1.8           5.1  virginica

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_width   150 non-null    float64
#  3   petal_length  150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_width  petal_length
# count    150.000000   150.000000   150.000000    150.000000
# mean       5.843333     3.057333     1.199333      3.758000
# std        0.828066     0.435866     0.762238      1.765298
# min        4.300000     2.000000     0.100000      1.000000
# 25%        5.100000     2.800000     0.300000      1.600000
# 50%        5.800000     3.000000     1.300000      4.350000
# 75%        6.400000     3.300000     1.800000      5.100000
# max        7.900000     4.400000     2.500000      6.900000

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank', 'Grace', 'Helen', 'Ian', 'Jack'],
    'Age': [23, 24, 22, None, 25, 24, None, 23, 22, 24],
    'Marks': [85, 90, 95, 88, None, 76, 89, None, 91, 93],
    'Gender': ['F', 'M', 'M', 'M', 'F', 'M', 'F', 'F', 'M', 'M'],
    'Passed': ['Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Yes']
}
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name   Age  Marks Gender Passed
# 0    Alice  23.0   85.0      F    Yes
# 1      Bob  24.0   90.0      M    Yes
# 2  Charlie  22.0   95.0      M    Yes
# 3    David   NaN   88.0      M    Yes
# 4      Eva  25.0    NaN      F     No
# 5    Frank  24.0   76.0      M     No
# 6    Grace   NaN   89.0      F    Yes
# 7    Helen  23.0    NaN      F     No
# 8      Ian  22.0   91.0      M    Yes
# 9     Jack  24.0   93.0      M    Yes

# %%
df.to_json("data1.json")

# %%
#looksups(head,tail,accessing,rows and  columns,loc,iloc,info)

# %%
df.tail()
# Out:
#     Name   Age  Marks Gender Passed
# 5  Frank  24.0   76.0      M     No
# 6  Grace   NaN   89.0      F    Yes
# 7  Helen  23.0    NaN      F     No
# 8    Ian  22.0   91.0      M    Yes
# 9   Jack  24.0   93.0      M    Yes

# %%
df.head()
# Out:
#       Name   Age  Marks Gender Passed
# 0    Alice  23.0   85.0      F    Yes
# 1      Bob  24.0   90.0      M    Yes
# 2  Charlie  22.0   95.0      M    Yes
# 3    David   NaN   88.0      M    Yes
# 4      Eva  25.0    NaN      F     No

# %%
df.Name
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4        Eva
# 5      Frank
# 6      Grace
# 7      Helen
# 8        Ian
# 9       Jack
# Name: Name, dtype: object

# %%
df['Name']
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4        Eva
# 5      Frank
# 6      Grace
# 7      Helen
# 8        Ian
# 9       Jack
# Name: Name, dtype: object

# %%
df.loc[1:6,"Age":"Gender"]
# Out:
#     Age  Marks Gender
# 1  24.0   90.0      M
# 2  22.0   95.0      M
# 3   NaN   88.0      M
# 4  25.0    NaN      F
# 5  24.0   76.0      M
# 6   NaN   89.0      F

# %%
df.iloc[0:4,0:3]
# Out:
#       Name   Age  Marks
# 0    Alice  23.0   85.0
# 1      Bob  24.0   90.0
# 2  Charlie  22.0   95.0
# 3    David   NaN   88.0

# %%
# adding(columns,rows)

# %%
df
# Out:
#       Name   Age  Marks Gender Passed
# 0    Alice  23.0   85.0      F    Yes
# 1      Bob  24.0   90.0      M    Yes
# 2  Charlie  22.0   95.0      M    Yes
# 3    David   NaN   88.0      M    Yes
# 4      Eva  25.0    NaN      F     No
# 5    Frank  24.0   76.0      M     No
# 6    Grace   NaN   89.0      F    Yes
# 7    Helen  23.0    NaN      F     No
# 8      Ian  22.0   91.0      M    Yes
# 9     Jack  24.0   93.0      M    Yes

# %%
def generate_grade(marks):
    if marks>90 and marks<=100:
        return "A+"
    elif marks>80 and marks<=90:
        return "A"
    elif marks>70 and marks<=80:
        return "B+"
    elif marks>60 and marks<=70:
        return "B"
    else:
        return "F"

# %%
generate_grade(59)
# Out:
# 'F'

# %%
df.Marks
# Out:
# 0    85.0
# 1    90.0
# 2    95.0
# 3    88.0
# 4     NaN
# 5    76.0
# 6    89.0
# 7     NaN
# 8    91.0
# 9    93.0
# Name: Marks, dtype: float64

# %%
grades=list(map(generate_grade,df.Marks))
grades
# Out:
# ['A', 'A', 'A+', 'A', 'F', 'B+', 'A', 'F', 'A+', 'A+']

# %%
df['Grades']=grades

# %%
df
# Out:
#       Name   Age  Marks Gender Passed Grades
# 0    Alice  23.0   85.0      F    Yes      A
# 1      Bob  24.0   90.0      M    Yes      A
# 2  Charlie  22.0   95.0      M    Yes     A+
# 3    David   NaN   88.0      M    Yes      A
# 4      Eva  25.0    NaN      F     No      F
# 5    Frank  24.0   76.0      M     No     B+
# 6    Grace   NaN   89.0      F    Yes      A
# 7    Helen  23.0    NaN      F     No      F
# 8      Ian  22.0   91.0      M    Yes     A+
# 9     Jack  24.0   93.0      M    Yes     A+

# %%
df[]
# Out:
#       Name   Age  Marks Gender Passed Grades
# 0    Alice  23.0   85.0      F    Yes      A
# 1      Bob  24.0   90.0      M    Yes      A
# 2  Charlie  22.0   95.0      M    Yes     A+
# 3    David   NaN   88.0      M    Yes      A
# 5    Frank  24.0   76.0      M     No     B+
# 6    Grace   NaN   89.0      F    Yes      A
# 8      Ian  22.0   91.0      M    Yes     A+
# 9     Jack  24.0   93.0      M    Yes     A+

# %%
df[df['Grades']!="F"]
# Out:
#       Name   Age  Marks Gender Passed Grades
# 0    Alice  23.0   85.0      F    Yes      A
# 1      Bob  24.0   90.0      M    Yes      A
# 2  Charlie  22.0   95.0      M    Yes     A+
# 3    David   NaN   88.0      M    Yes      A
# 5    Frank  24.0   76.0      M     No     B+
# 6    Grace   NaN   89.0      F    Yes      A
# 8      Ian  22.0   91.0      M    Yes     A+
# 9     Jack  24.0   93.0      M    Yes     A+

# %%
df[df['Grades']=="A" | df['Grades']=="A+"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\ops\array_ops.py:362, in na_logical_op(x, y, op)
#     353 try:
#     354     # For exposition, write:
#     355     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     360     # Then Cases where this goes through without raising include:
#     361     #  (xint or xbool) and (yint or bool)
# --> 362     result = op(x, y)
#     363 except TypeError:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\roperator.py:58, in ror_(left, right)
#      57 def ror_(left, right):
# ---> 58     return operator.or_(right, left)
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ...

# %%
df['Grades']=="A+"
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8     True
# 9     True
# Name: Grades, dtype: bool

# %%
df['Grades']=="A"
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# 9    False
# Name: Grades, dtype: bool

# %%
df[(df['Gender']=="M") & (df['Grades']=="A")] # or-> "|"
# Out:
#     Name   Age  Marks Gender Passed Grades
# 1    Bob  24.0   90.0      M    Yes      A
# 3  David   NaN   88.0      M    Yes      A

# %%
df
# Out:
#       Name   Age  Marks Gender Passed Grades
# 0    Alice  23.0   85.0      F    Yes      A
# 1      Bob  24.0   90.0      M    Yes      A
# 2  Charlie  22.0   95.0      M    Yes     A+
# 3    David   NaN   88.0      M    Yes      A
# 4      Eva  25.0    NaN      F     No      F
# 5    Frank  24.0   76.0      M     No     B+
# 6    Grace   NaN   89.0      F    Yes      A
# 7    Helen  23.0    NaN      F     No      F
# 8      Ian  22.0   91.0      M    Yes     A+
# 9     Jack  24.0   93.0      M    Yes     A+

# %%
# cleaning(isnull,notnull,dropna,fillna())

# %%
df.Marks.mean()
# Out:
# 88.375

# %%
df.Marks
# Out:
# 0    85.0
# 1    90.0
# 2    95.0
# 3    88.0
# 4     NaN
# 5    76.0
# 6    89.0
# 7     NaN
# 8    91.0
# 9    93.0
# Name: Marks, dtype: float64

# %%
df.Marks.fillna()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 df.Marks.fillna()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:7293, in NDFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#    7286         if ctr <= ref_count:
#    7287             warnings.warn(
#    7288                 _chained_assignment_warning_method_msg,
#    7289                 FutureWarning,
#    7290                 stacklevel=2,
#    7291             )
# -> 7293 value, method = validate_fillna_kwargs(value, method)
#    7294 if method is not None:
#    7295     warnings.warn(
#    7296         f"{type(self).__name__}.fillna with 'method' is deprecated and "
#    7297         "will raise in a future version. Use obj.ffill() or obj.bfill() "
#    (...)
#    7300         stacklevel=find_stack_level(),
#    7301     )
#
# ...

# %%
df
# Out:
#       Name   Age  Marks Gender Passed Grades
# 0    Alice  23.0   85.0      F    Yes      A
# 1      Bob  24.0   90.0      M    Yes      A
# 2  Charlie  22.0   95.0      M    Yes     A+
# 3    David   NaN   88.0      M    Yes      A
# 4      Eva  25.0    NaN      F     No      F
# 5    Frank  24.0   76.0      M     No     B+
# 6    Grace   NaN   89.0      F    Yes      A
# 7    Helen  23.0    NaN      F     No      F
# 8      Ian  22.0   91.0      M    Yes     A+
# 9     Jack  24.0   93.0      M    Yes     A+

# %%
df["Marks"].fillna(90)
# Out:
# 0    85.0
# 1    90.0
# 2    95.0
# 3    88.0
# 4    90.0
# 5    76.0
# 6    89.0
# 7    90.0
# 8    91.0
# 9    93.0
# Name: Marks, dtype: float64

# %%
df["Marks"].fillna(90)

# %%
df
# Out:
#       Name   Age  Marks Gender Passed Grades
# 0    Alice  23.0   85.0      F    Yes      A
# 1      Bob  24.0   90.0      M    Yes      A
# 2  Charlie  22.0   95.0      M    Yes     A+
# 3    David   NaN   88.0      M    Yes      A
# 4      Eva  25.0   90.0      F     No      F
# 5    Frank  24.0   76.0      M     No     B+
# 6    Grace   NaN   89.0      F    Yes      A
# 7    Helen  23.0   90.0      F     No      F
# 8      Ian  22.0   91.0      M    Yes     A+
# 9     Jack  24.0   93.0      M    Yes     A+

# %%
df.Age.mean()
# Out:
# 23.375

# %%
df.Age.fillna(df.Age.mean(),inplace=True)

# %%
df
# Out:
#       Name     Age  Marks Gender Passed Grades
# 0    Alice  23.000   85.0      F    Yes      A
# 1      Bob  24.000   90.0      M    Yes      A
# 2  Charlie  22.000   95.0      M    Yes     A+
# 3    David  23.375   88.0      M    Yes      A
# 4      Eva  25.000   90.0      F     No      F
# 5    Frank  24.000   76.0      M     No     B+
# 6    Grace  23.375   89.0      F    Yes      A
# 7    Helen  23.000   90.0      F     No      F
# 8      Ian  22.000   91.0      M    Yes     A+
# 9     Jack  24.000   93.0      M    Yes     A+

# %%
df.Age.dtype
# Out:
# dtype('float64')

# %%
df.Age.astype(int)
# Out:
# 0    23
# 1    24
# 2    22
# 3    23
# 4    25
# 5    24
# 6    23
# 7    23
# 8    22
# 9    24
# Name: Age, dtype: int32

# %%
df.Age=df.Age.astype(int)

# %%
df
# Out:
#       Name  Age  Marks Gender Passed Grades
# 0    Alice   23   85.0      F    Yes      A
# 1      Bob   24   90.0      M    Yes      A
# 2  Charlie   22   95.0      M    Yes     A+
# 3    David   23   88.0      M    Yes      A
# 4      Eva   25   90.0      F     No      F
# 5    Frank   24   76.0      M     No     B+
# 6    Grace   23   89.0      F    Yes      A
# 7    Helen   23   90.0      F     No      F
# 8      Ian   22   91.0      M    Yes     A+
# 9     Jack   24   93.0      M    Yes     A+

# %%
df.isnull()
# Out:
#     Name    Age  Marks  Gender  Passed  Grades
# 0  False  False  False   False   False   False
# 1  False  False  False   False   False   False
# 2  False  False  False   False   False   False
# 3  False  False  False   False   False   False
# 4  False  False  False   False   False   False
# 5  False  False  False   False   False   False
# 6  False  False  False   False   False   False
# 7  False  False  False   False   False   False
# 8  False  False  False   False   False   False
# 9  False  False  False   False   False   False

# %%
df.Grades=df.Marks.map(generate_grade)

# %%
df.Passed="Yes"

# %%
df
# Out:
#       Name  Age  Marks Gender Passed Grades
# 0    Alice   23   85.0      F    Yes      A
# 1      Bob   24   90.0      M    Yes      A
# 2  Charlie   22   95.0      M    Yes     A+
# 3    David   23   88.0      M    Yes      A
# 4      Eva   25   90.0      F    Yes      A
# 5    Frank   24   76.0      M    Yes     B+
# 6    Grace   23   89.0      F    Yes      A
# 7    Helen   23   90.0      F    Yes      A
# 8      Ian   22   91.0      M    Yes     A+
# 9     Jack   24   93.0      M    Yes     A+

# %%
#replace
#joins
#groupby
#dublicates duplicated()  drop_duplicates()

# %%
df
# Out:
#       Name  Age  Marks Gender Passed Grades
# 0    Alice   23   85.0      F    Yes      A
# 1      Bob   24   90.0      M    Yes      A
# 2  Charlie   22   95.0      M    Yes     A+
# 3    David   23   88.0      M    Yes      A
# 4      Eva   25   90.0      F    Yes      A
# 5    Frank   24   76.0      M    Yes     B+
# 6    Grace   23   89.0      F    Yes      A
# 7    Helen   23   90.0      F    Yes      A
# 8      Ian   22   91.0      M    Yes     A+
# 9     Jack   24   93.0      M    Yes     A+

# %%
df.Passed=df.Passed.replace("Yes","True")

# %%
df
# Out:
#       Name  Age  Marks Gender Passed Grades
# 0    Alice   23   85.0      F   True      A
# 1      Bob   24   90.0      M   True      A
# 2  Charlie   22   95.0      M   True     A+
# 3    David   23   88.0      M   True      A
# 4      Eva   25   90.0      F   True      A
# 5    Frank   24   76.0      M   True     B+
# 6    Grace   23   89.0      F   True      A
# 7    Helen   23   90.0      F   True      A
# 8      Ian   22   91.0      M   True     A+
# 9     Jack   24   93.0      M   True     A+

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank', 'Grace', 'Helen', 'Ian', 'Jack'],
    'Age': [23, 24, 22, None, 25, 24, None, 23, 22, 24],
    'Marks': [85, 90, 95, 88, None, 76, 89, None, 91, 93],
    'Gender': ['F', 'M', 'M', 'M', 'F', 'M', 'F', 'F', 'M', 'M'],
    'Passed': ['Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Yes']
}
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name   Age  Marks Gender Passed
# 0    Alice  23.0   85.0      F    Yes
# 1      Bob  24.0   90.0      M    Yes
# 2  Charlie  22.0   95.0      M    Yes
# 3    David   NaN   88.0      M    Yes
# 4      Eva  25.0    NaN      F     No
# 5    Frank  24.0   76.0      M     No
# 6    Grace   NaN   89.0      F    Yes
# 7    Helen  23.0    NaN      F     No
# 8      Ian  22.0   91.0      M    Yes
# 9     Jack  24.0   93.0      M    Yes

# %%
df
# Out:
#       Name   Age  Marks Gender Passed
# 0    Alice  23.0   85.0      F    Yes
# 1      Bob  24.0   90.0      M    Yes
# 2  Charlie  22.0   95.0      M    Yes
# 3    David   NaN   88.0      M    Yes
# 4      Eva  25.0    NaN      F     No
# 5    Frank  24.0   76.0      M     No
# 6    Grace   NaN   89.0      F    Yes
# 7    Helen  23.0    NaN      F     No
# 8      Ian  22.0   91.0      M    Yes
# 9     Jack  24.0   93.0      M    Yes

# %%
#access all not null values

# %%
df[(df["Age"].notnull()) & (df["Marks"].notnull())]
# Out:
#       Name   Age  Marks Gender Passed
# 0    Alice  23.0   85.0      F    Yes
# 1      Bob  24.0   90.0      M    Yes
# 2  Charlie  22.0   95.0      M    Yes
# 5    Frank  24.0   76.0      M     No
# 8      Ian  22.0   91.0      M    Yes
# 9     Jack  24.0   93.0      M    Yes

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
pd.read_
